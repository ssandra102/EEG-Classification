# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# %%
# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 60, Samples = 151, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
## trainer 

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
# from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# PyRiemann imports
from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace

from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# while the default tensorflow ordering is 'channels_last' we set it here
# to be explicit in case if the user has changed the default ordering
K.set_image_data_format('channels_last')

##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw.fif'
event_fname = str(data_path) + '\MEG\sample\sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 2 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 2.00 Hz: -6.02 dB

# %%
# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels
X.shape
# Out:
# (288, 60, 151)

# %%
kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NHWC (trials, channels, samples, kernels) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], chans, samples, kernels)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, samples, kernels)
X_test       = X_test.reshape(X_test.shape[0], chans, samples, kernels)
   
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (144, 60, 151, 1)
# 144 train samples
# 72 test samples

# %%
X_test.shape
# Out:
# (72, 60, 151, 1)

# %%
# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = ShallowConvNet(nb_classes = 4, Chans = 60, Samples = 151, dropoutRate = 0.5)

model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='checkpoint1.h5', verbose=1,
                               save_best_only=True)

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 2.42548, saving model to checkpoint1.h5
# 9/9 - 1s - loss: 2.1285 - accuracy: 0.2292 - val_loss: 2.4255 - val_accuracy: 0.2361 - 1s/epoch - 136ms/step
# Epoch 2/300
# c:\Users\sandr\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 2.42548
# 9/9 - 0s - loss: 1.4115 - accuracy: 0.2986 - val_loss: 3.0102 - val_accuracy: 0.2500 - 328ms/epoch - 36ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 2.42548
# 9/9 - 0s - loss: 1.3349 - accuracy: 0.4236 - val_loss: 2.6490 - val_accuracy: 0.2500 - 324ms/epoch - 36ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 2.42548 to 1.86862, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.2375 - accuracy: 0.4792 - val_loss: 1.8686 - val_accuracy: 0.2500 - 345ms/epoch - 38ms/step
# Epoch 5/300
#
# Epoch 5: val_loss improved from 1.86862 to 1.64822, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.1629 - accuracy: 0.5139 - val_loss: 1.6482 - val_accuracy: 0.2639 - 389ms/epoch - 43ms/step
# Epoch 6/300
#
# Epoch 6: val_loss improved from 1.64822 to 1.60548, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0882 - accuracy: 0.5764 - val_loss: 1.6055 - val_accuracy: 0.2222 - 340ms/epoch - 38ms/step
# Epoch 7/300
#
# Epoch 7: val_loss improved from 1.60548 to 1.47291, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0556 - accuracy: 0.6181 - val_loss: 1.4729 - val_accuracy: 0.2917 - 354ms/epoch - 39ms/step
# Epoch 8/300
#
# Epoch 8: val_loss improved from 1.47291 to 1.44068, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 1.0223 - accuracy: 0.5903 - val_loss: 1.4407 - val_accuracy: 0.2778 - 368ms/epoch - 41ms/step
# Epoch 9/300
#
# Epoch 9: val_loss improved from 1.44068 to 1.23376, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.9042 - accuracy: 0.6667 - val_loss: 1.2338 - val_accuracy: 0.3611 - 361ms/epoch - 40ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 1.23376
# 9/9 - 0s - loss: 0.8832 - accuracy: 0.7153 - val_loss: 1.3111 - val_accuracy: 0.3333 - 343ms/epoch - 38ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 1.23376
# 9/9 - 0s - loss: 0.7987 - accuracy: 0.7361 - val_loss: 1.2758 - val_accuracy: 0.3333 - 326ms/epoch - 36ms/step
# Epoch 12/300
#
# Epoch 12: val_loss improved from 1.23376 to 1.11779, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.7097 - accuracy: 0.7778 - val_loss: 1.1178 - val_accuracy: 0.4722 - 348ms/epoch - 39ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 1.11779
# 9/9 - 0s - loss: 0.6399 - accuracy: 0.8542 - val_loss: 1.2547 - val_accuracy: 0.3750 - 305ms/epoch - 34ms/step
# Epoch 14/300
#
# Epoch 14: val_loss improved from 1.11779 to 1.08514, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5730 - accuracy: 0.8681 - val_loss: 1.0851 - val_accuracy: 0.5000 - 322ms/epoch - 36ms/step
# Epoch 15/300
#
# Epoch 15: val_loss improved from 1.08514 to 1.01961, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.5144 - accuracy: 0.8750 - val_loss: 1.0196 - val_accuracy: 0.5556 - 362ms/epoch - 40ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 1.01961 to 0.99157, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4833 - accuracy: 0.9097 - val_loss: 0.9916 - val_accuracy: 0.6528 - 361ms/epoch - 40ms/step
# Epoch 17/300
#
# Epoch 17: val_loss improved from 0.99157 to 0.97549, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.4078 - accuracy: 0.9306 - val_loss: 0.9755 - val_accuracy: 0.6250 - 365ms/epoch - 41ms/step
# Epoch 18/300
#
# Epoch 18: val_loss improved from 0.97549 to 0.90149, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3467 - accuracy: 0.9514 - val_loss: 0.9015 - val_accuracy: 0.6667 - 337ms/epoch - 37ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 0.90149 to 0.84102, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.3390 - accuracy: 0.9653 - val_loss: 0.8410 - val_accuracy: 0.6389 - 328ms/epoch - 36ms/step
# Epoch 20/300
#
# Epoch 20: val_loss improved from 0.84102 to 0.81530, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.2927 - accuracy: 0.9653 - val_loss: 0.8153 - val_accuracy: 0.6667 - 330ms/epoch - 37ms/step
# Epoch 21/300
#
# Epoch 21: val_loss improved from 0.81530 to 0.75800, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.2572 - accuracy: 0.9931 - val_loss: 0.7580 - val_accuracy: 0.7083 - 337ms/epoch - 37ms/step
# Epoch 22/300
#
# Epoch 22: val_loss improved from 0.75800 to 0.74529, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.2183 - accuracy: 0.9931 - val_loss: 0.7453 - val_accuracy: 0.7639 - 340ms/epoch - 38ms/step
# Epoch 23/300
#
# Epoch 23: val_loss did not improve from 0.74529
# 9/9 - 0s - loss: 0.2196 - accuracy: 1.0000 - val_loss: 0.7525 - val_accuracy: 0.6528 - 340ms/epoch - 38ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 0.74529 to 0.72825, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.1962 - accuracy: 0.9792 - val_loss: 0.7282 - val_accuracy: 0.7222 - 374ms/epoch - 42ms/step
# Epoch 25/300
#
# Epoch 25: val_loss improved from 0.72825 to 0.67514, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.1638 - accuracy: 0.9931 - val_loss: 0.6751 - val_accuracy: 0.7083 - 380ms/epoch - 42ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 0.67514 to 0.67180, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.1615 - accuracy: 0.9861 - val_loss: 0.6718 - val_accuracy: 0.7500 - 376ms/epoch - 42ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.67180
# 9/9 - 0s - loss: 0.1180 - accuracy: 1.0000 - val_loss: 0.6831 - val_accuracy: 0.6667 - 330ms/epoch - 37ms/step
# Epoch 28/300
#
# Epoch 28: val_loss did not improve from 0.67180
# 9/9 - 0s - loss: 0.1453 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.6806 - 318ms/epoch - 35ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.67180
# 9/9 - 0s - loss: 0.1130 - accuracy: 0.9931 - val_loss: 0.6843 - val_accuracy: 0.6667 - 329ms/epoch - 37ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 0.67180 to 0.63577, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.1239 - accuracy: 1.0000 - val_loss: 0.6358 - val_accuracy: 0.7639 - 342ms/epoch - 38ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 0.63577 to 0.62505, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.1139 - accuracy: 1.0000 - val_loss: 0.6250 - val_accuracy: 0.7083 - 363ms/epoch - 40ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.62505
# 9/9 - 0s - loss: 0.1073 - accuracy: 1.0000 - val_loss: 0.6516 - val_accuracy: 0.7361 - 312ms/epoch - 35ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.62505
# 9/9 - 0s - loss: 0.0995 - accuracy: 1.0000 - val_loss: 0.6535 - val_accuracy: 0.7222 - 320ms/epoch - 36ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 0.62505 to 0.62042, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.6204 - val_accuracy: 0.7778 - 327ms/epoch - 36ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.62042
# 9/9 - 0s - loss: 0.0995 - accuracy: 1.0000 - val_loss: 0.6227 - val_accuracy: 0.7639 - 304ms/epoch - 34ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.62042
# 9/9 - 0s - loss: 0.0808 - accuracy: 1.0000 - val_loss: 0.6219 - val_accuracy: 0.7917 - 310ms/epoch - 34ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.62042
# 9/9 - 0s - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.6514 - val_accuracy: 0.6944 - 310ms/epoch - 34ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.62042
# 9/9 - 0s - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.6443 - val_accuracy: 0.7778 - 306ms/epoch - 34ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 0.62042 to 0.61429, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.6143 - val_accuracy: 0.7222 - 329ms/epoch - 37ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 0.61429 to 0.57322, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0675 - accuracy: 1.0000 - val_loss: 0.5732 - val_accuracy: 0.7639 - 362ms/epoch - 40ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.57322
# 9/9 - 0s - loss: 0.0571 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.7639 - 345ms/epoch - 38ms/step
# Epoch 42/300
#
# Epoch 42: val_loss improved from 0.57322 to 0.56272, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.5627 - val_accuracy: 0.7639 - 345ms/epoch - 38ms/step
# Epoch 43/300
#
# Epoch 43: val_loss improved from 0.56272 to 0.55158, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.5516 - val_accuracy: 0.7500 - 353ms/epoch - 39ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.55158
# 9/9 - 0s - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 0.7500 - 329ms/epoch - 37ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.55158
# 9/9 - 0s - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.5774 - val_accuracy: 0.7639 - 314ms/epoch - 35ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.55158
# 9/9 - 0s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.5580 - val_accuracy: 0.7639 - 337ms/epoch - 37ms/step
# Epoch 47/300
#
# Epoch 47: val_loss improved from 0.55158 to 0.53105, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.7778 - 347ms/epoch - 39ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 0.53105 to 0.52962, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.5296 - val_accuracy: 0.8056 - 347ms/epoch - 39ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.52962
# 9/9 - 0s - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.5579 - val_accuracy: 0.8056 - 315ms/epoch - 35ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.52962
# 9/9 - 0s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8194 - 328ms/epoch - 36ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 0.52962 to 0.51628, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.7778 - 346ms/epoch - 38ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.51628
# 9/9 - 0s - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.5298 - val_accuracy: 0.7917 - 320ms/epoch - 36ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.51628
# 9/9 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.5384 - val_accuracy: 0.7639 - 325ms/epoch - 36ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 0.51628 to 0.50472, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.5047 - val_accuracy: 0.8333 - 357ms/epoch - 40ms/step
# Epoch 55/300
#
# Epoch 55: val_loss improved from 0.50472 to 0.50470, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.5047 - val_accuracy: 0.8333 - 363ms/epoch - 40ms/step
# Epoch 56/300
#
# Epoch 56: val_loss improved from 0.50470 to 0.47074, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.4707 - val_accuracy: 0.8194 - 338ms/epoch - 38ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.7639 - 313ms/epoch - 35ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.5276 - val_accuracy: 0.7917 - 303ms/epoch - 34ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.8056 - 316ms/epoch - 35ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.7639 - 305ms/epoch - 34ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.5382 - val_accuracy: 0.7917 - 316ms/epoch - 35ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.5385 - val_accuracy: 0.7500 - 309ms/epoch - 34ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.47074
# 9/9 - 0s - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.5379 - val_accuracy: 0.7917 - 308ms/epoch - 34ms/step
# Epoch 64/300
#
# Epoch 64: val_loss improved from 0.47074 to 0.46622, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.8056 - 340ms/epoch - 38ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8194 - 325ms/epoch - 36ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.7639 - 317ms/epoch - 35ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.7917 - 305ms/epoch - 34ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.4827 - val_accuracy: 0.7917 - 317ms/epoch - 35ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.7639 - 303ms/epoch - 34ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8194 - 327ms/epoch - 36ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.8194 - 336ms/epoch - 37ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.4807 - val_accuracy: 0.8056 - 331ms/epoch - 37ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.4750 - val_accuracy: 0.7917 - 299ms/epoch - 33ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.7778 - 308ms/epoch - 34ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.46622
# 9/9 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.7778 - 314ms/epoch - 35ms/step
# Epoch 76/300
#
# Epoch 76: val_loss improved from 0.46622 to 0.45531, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.4553 - val_accuracy: 0.7917 - 323ms/epoch - 36ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.45531
# 9/9 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7917 - 327ms/epoch - 36ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.45531
# 9/9 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.7917 - 335ms/epoch - 37ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.45531
# 9/9 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.8056 - 324ms/epoch - 36ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.45531
# 9/9 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.7917 - 305ms/epoch - 34ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.45531
# 9/9 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8056 - 325ms/epoch - 36ms/step
# Epoch 82/300
#
# Epoch 82: val_loss improved from 0.45531 to 0.44757, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.4476 - val_accuracy: 0.8333 - 351ms/epoch - 39ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.7917 - 350ms/epoch - 39ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.5046 - val_accuracy: 0.7639 - 323ms/epoch - 36ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 0.7778 - 316ms/epoch - 35ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.7917 - 336ms/epoch - 37ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.7917 - 327ms/epoch - 36ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.4831 - val_accuracy: 0.7639 - 313ms/epoch - 35ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.4729 - val_accuracy: 0.7778 - 330ms/epoch - 37ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.8194 - 328ms/epoch - 36ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8194 - 306ms/epoch - 34ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.8056 - 295ms/epoch - 33ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.4629 - val_accuracy: 0.7917 - 304ms/epoch - 34ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.4651 - val_accuracy: 0.7917 - 308ms/epoch - 34ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.7917 - 310ms/epoch - 34ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.4823 - val_accuracy: 0.7639 - 308ms/epoch - 34ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.7917 - 315ms/epoch - 35ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.7778 - 324ms/epoch - 36ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.4676 - val_accuracy: 0.7778 - 348ms/epoch - 39ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5060 - val_accuracy: 0.7778 - 321ms/epoch - 36ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4820 - val_accuracy: 0.7778 - 316ms/epoch - 35ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.7917 - 331ms/epoch - 37ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.7917 - 325ms/epoch - 36ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.4636 - val_accuracy: 0.7917 - 328ms/epoch - 36ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.7778 - 325ms/epoch - 36ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8056 - 321ms/epoch - 36ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.8194 - 345ms/epoch - 38ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.4635 - val_accuracy: 0.7917 - 344ms/epoch - 38ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.7778 - 337ms/epoch - 37ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4748 - val_accuracy: 0.8056 - 331ms/epoch - 37ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.44757
# 9/9 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4807 - val_accuracy: 0.8056 - 328ms/epoch - 36ms/step
# Epoch 112/300
#
# Epoch 112: val_loss improved from 0.44757 to 0.43055, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.4305 - val_accuracy: 0.8056 - 349ms/epoch - 39ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4433 - val_accuracy: 0.8056 - 334ms/epoch - 37ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4799 - val_accuracy: 0.7917 - 322ms/epoch - 36ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.7778 - 318ms/epoch - 35ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8056 - 326ms/epoch - 36ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.7778 - 324ms/epoch - 36ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8056 - 320ms/epoch - 36ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4897 - val_accuracy: 0.8194 - 313ms/epoch - 35ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.43055
# 9/9 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.7917 - 319ms/epoch - 35ms/step
# Epoch 121/300
#
# Epoch 121: val_loss improved from 0.43055 to 0.42626, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.4263 - val_accuracy: 0.8194 - 357ms/epoch - 40ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.8056 - 328ms/epoch - 36ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.8056 - 321ms/epoch - 36ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4659 - val_accuracy: 0.8750 - 316ms/epoch - 35ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.5259 - val_accuracy: 0.8056 - 316ms/epoch - 35ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.8056 - 306ms/epoch - 34ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4785 - val_accuracy: 0.7917 - 303ms/epoch - 34ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.7778 - 299ms/epoch - 33ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.7778 - 300ms/epoch - 33ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.7778 - 315ms/epoch - 35ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.8056 - 309ms/epoch - 34ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8056 - 302ms/epoch - 34ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.7500 - 304ms/epoch - 34ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.8194 - 300ms/epoch - 33ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.7500 - 306ms/epoch - 34ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.4975 - val_accuracy: 0.7917 - 314ms/epoch - 35ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.7639 - 317ms/epoch - 35ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4761 - val_accuracy: 0.7917 - 309ms/epoch - 34ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.7917 - 343ms/epoch - 38ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.7778 - 325ms/epoch - 36ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8472 - 318ms/epoch - 35ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.5743 - val_accuracy: 0.7778 - 331ms/epoch - 37ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.4766 - val_accuracy: 0.7917 - 319ms/epoch - 35ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4878 - val_accuracy: 0.7778 - 304ms/epoch - 34ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4928 - val_accuracy: 0.7778 - 310ms/epoch - 34ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.7778 - 309ms/epoch - 34ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.6368 - val_accuracy: 0.7917 - 304ms/epoch - 34ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.5640 - val_accuracy: 0.7500 - 315ms/epoch - 35ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.8056 - 309ms/epoch - 34ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0401 - accuracy: 0.9931 - val_loss: 0.5623 - val_accuracy: 0.8056 - 305ms/epoch - 34ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.7934 - val_accuracy: 0.6806 - 299ms/epoch - 33ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0752 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.5833 - 310ms/epoch - 34ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0772 - accuracy: 0.9931 - val_loss: 1.3055 - val_accuracy: 0.4583 - 302ms/epoch - 34ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0631 - accuracy: 1.0000 - val_loss: 1.0558 - val_accuracy: 0.4583 - 312ms/epoch - 35ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.5993 - val_accuracy: 0.7500 - 305ms/epoch - 34ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.8194 - 310ms/epoch - 34ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 0.7778 - 306ms/epoch - 34ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.7778 - 338ms/epoch - 38ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.8056 - 311ms/epoch - 35ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.7917 - 311ms/epoch - 35ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.7917 - 300ms/epoch - 33ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.7917 - 313ms/epoch - 35ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.7917 - 316ms/epoch - 35ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.8056 - 325ms/epoch - 36ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4343 - val_accuracy: 0.8056 - 327ms/epoch - 36ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.7639 - 321ms/epoch - 36ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.8056 - 343ms/epoch - 38ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.7778 - 318ms/epoch - 35ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.7917 - 329ms/epoch - 37ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4659 - val_accuracy: 0.7917 - 326ms/epoch - 36ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4670 - val_accuracy: 0.8194 - 314ms/epoch - 35ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.8056 - 317ms/epoch - 35ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.7917 - 314ms/epoch - 35ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4465 - val_accuracy: 0.7917 - 332ms/epoch - 37ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8333 - 338ms/epoch - 38ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.8056 - 336ms/epoch - 37ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.7778 - 326ms/epoch - 36ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.7917 - 311ms/epoch - 35ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.7917 - 313ms/epoch - 35ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.7778 - 316ms/epoch - 35ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.7778 - 300ms/epoch - 33ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.8056 - 292ms/epoch - 32ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4569 - val_accuracy: 0.8056 - 295ms/epoch - 33ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4970 - val_accuracy: 0.8194 - 306ms/epoch - 34ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8194 - 306ms/epoch - 34ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.8056 - 337ms/epoch - 37ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4472 - val_accuracy: 0.7917 - 308ms/epoch - 34ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.7917 - 307ms/epoch - 34ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4530 - val_accuracy: 0.8194 - 301ms/epoch - 33ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4578 - val_accuracy: 0.8333 - 305ms/epoch - 34ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4684 - val_accuracy: 0.8056 - 312ms/epoch - 35ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8056 - 303ms/epoch - 34ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8194 - 304ms/epoch - 34ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.8056 - 307ms/epoch - 34ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.8056 - 308ms/epoch - 34ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.7639 - 334ms/epoch - 37ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.8194 - 360ms/epoch - 40ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8056 - 309ms/epoch - 34ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4482 - val_accuracy: 0.8056 - 312ms/epoch - 35ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4426 - val_accuracy: 0.8194 - 322ms/epoch - 36ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.8056 - 323ms/epoch - 36ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.8056 - 340ms/epoch - 38ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.7917 - 324ms/epoch - 36ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.8056 - 308ms/epoch - 34ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8194 - 316ms/epoch - 35ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.8194 - 319ms/epoch - 35ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8333 - 315ms/epoch - 35ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4475 - val_accuracy: 0.8056 - 305ms/epoch - 34ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.8194 - 315ms/epoch - 35ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4267 - val_accuracy: 0.8194 - 307ms/epoch - 34ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.8056 - 307ms/epoch - 34ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.7639 - 351ms/epoch - 39ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4593 - val_accuracy: 0.7917 - 323ms/epoch - 36ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.4553 - val_accuracy: 0.8333 - 323ms/epoch - 36ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4575 - val_accuracy: 0.8056 - 308ms/epoch - 34ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.7917 - 306ms/epoch - 34ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.8194 - 299ms/epoch - 33ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8472 - 301ms/epoch - 33ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4762 - val_accuracy: 0.8056 - 306ms/epoch - 34ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8194 - 303ms/epoch - 34ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.8333 - 303ms/epoch - 34ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8056 - 304ms/epoch - 34ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4309 - val_accuracy: 0.8194 - 322ms/epoch - 36ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.8333 - 317ms/epoch - 35ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.8194 - 307ms/epoch - 34ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 0.8194 - 314ms/epoch - 35ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.8194 - 294ms/epoch - 33ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4496 - val_accuracy: 0.8472 - 305ms/epoch - 34ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4784 - val_accuracy: 0.8194 - 299ms/epoch - 33ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.42626
# 9/9 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.4738 - val_accuracy: 0.8056 - 296ms/epoch - 33ms/step
# Epoch 231/300
#
# Epoch 231: val_loss improved from 0.42626 to 0.42418, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4242 - val_accuracy: 0.8333 - 343ms/epoch - 38ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4493 - val_accuracy: 0.8333 - 311ms/epoch - 35ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4446 - val_accuracy: 0.8194 - 303ms/epoch - 34ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.8333 - 303ms/epoch - 34ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.8194 - 309ms/epoch - 34ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.8194 - 327ms/epoch - 36ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4480 - val_accuracy: 0.8056 - 302ms/epoch - 34ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 0.8472 - 310ms/epoch - 34ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.8194 - 309ms/epoch - 34ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.8056 - 316ms/epoch - 35ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4656 - val_accuracy: 0.7917 - 309ms/epoch - 34ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5646 - val_accuracy: 0.7639 - 312ms/epoch - 35ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.7639 - 315ms/epoch - 35ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.8333 - 311ms/epoch - 35ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.8472 - 301ms/epoch - 33ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8333 - 307ms/epoch - 34ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8194 - 325ms/epoch - 36ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.8056 - 310ms/epoch - 34ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4561 - val_accuracy: 0.8472 - 318ms/epoch - 35ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4454 - val_accuracy: 0.8333 - 318ms/epoch - 35ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4412 - val_accuracy: 0.8333 - 317ms/epoch - 35ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4633 - val_accuracy: 0.8194 - 298ms/epoch - 33ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.8333 - 298ms/epoch - 33ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.8194 - 308ms/epoch - 34ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8056 - 298ms/epoch - 33ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8333 - 307ms/epoch - 34ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.8333 - 315ms/epoch - 35ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.42418
# 9/9 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.8472 - 301ms/epoch - 33ms/step
# Epoch 259/300
#
# Epoch 259: val_loss improved from 0.42418 to 0.42091, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4209 - val_accuracy: 0.8194 - 316ms/epoch - 35ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5325 - val_accuracy: 0.7639 - 304ms/epoch - 34ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.8333 - 309ms/epoch - 34ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.8194 - 304ms/epoch - 34ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.8194 - 304ms/epoch - 34ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6121 - val_accuracy: 0.7639 - 329ms/epoch - 37ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.8472 - 310ms/epoch - 34ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8333 - 309ms/epoch - 34ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.42091
# 9/9 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.8194 - 302ms/epoch - 34ms/step
# Epoch 268/300
#
# Epoch 268: val_loss improved from 0.42091 to 0.41547, saving model to checkpoint1.h5
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4155 - val_accuracy: 0.8472 - 326ms/epoch - 36ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.8472 - 319ms/epoch - 35ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4407 - val_accuracy: 0.8194 - 308ms/epoch - 34ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.8472 - 331ms/epoch - 37ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4815 - val_accuracy: 0.7917 - 314ms/epoch - 35ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4629 - val_accuracy: 0.8333 - 314ms/epoch - 35ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.8472 - 308ms/epoch - 34ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.8333 - 305ms/epoch - 34ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4467 - val_accuracy: 0.8472 - 323ms/epoch - 36ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.8333 - 318ms/epoch - 35ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4386 - val_accuracy: 0.8472 - 299ms/epoch - 33ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.8194 - 322ms/epoch - 36ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4343 - val_accuracy: 0.8333 - 295ms/epoch - 33ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4442 - val_accuracy: 0.8194 - 287ms/epoch - 32ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.8472 - 302ms/epoch - 34ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.8472 - 304ms/epoch - 34ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.8194 - 297ms/epoch - 33ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8056 - 308ms/epoch - 34ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.4390 - val_accuracy: 0.8333 - 322ms/epoch - 36ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.8333 - 303ms/epoch - 34ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.8194 - 294ms/epoch - 33ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8194 - 309ms/epoch - 34ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.8194 - 302ms/epoch - 34ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8333 - 305ms/epoch - 34ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4496 - val_accuracy: 0.8333 - 315ms/epoch - 35ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4226 - val_accuracy: 0.8472 - 302ms/epoch - 34ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.7778 - 319ms/epoch - 35ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4517 - val_accuracy: 0.8472 - 311ms/epoch - 35ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.7917 - 317ms/epoch - 35ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.8333 - 294ms/epoch - 33ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.8611 - 296ms/epoch - 33ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.5605 - val_accuracy: 0.8194 - 310ms/epoch - 34ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.41547
# 9/9 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.8611 - 305ms/epoch - 34ms/step

# %%
# make prediction on test set.

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# 3/3 [==============================] - 0s 10ms/step
# Classification accuracy: 0.986111

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score
from joblib import dump, load

# %%
temp = Y_test.argmax(axis=-1)
conf_matrix = confusion_matrix(temp, preds)
accuracy = accuracy_score(temp, preds)
precision = precision_score(temp, preds, average='weighted')
recall = recall_score(temp, preds, average='weighted')

print(f" Evaluation:")
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print("\n")

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title(f'Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
#  Evaluation:
# Accuracy: 0.99
# Precision: 0.99
# Recall: 0.99
